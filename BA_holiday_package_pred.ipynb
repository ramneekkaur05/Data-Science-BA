# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('customer_booking.csv',encoding='latin-1')

# %%
df.head(10)
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
# 5               1      Internet  RoundTrip              3              48
# 6               3      Internet  RoundTrip            201              33
# 7               2      Internet  RoundTrip            238              19
# 8               1      Internet  RoundTrip             80              22
# 9               1        Mobile  RoundTrip            378              30
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# ...

# %%
df.shape
# Out:
# (50000, 14)

# %%
data = df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   num_passengers         50000 non-null  int64
#  1   sales_channel          50000 non-null  object
#  2   trip_type              50000 non-null  object
#  3   purchase_lead          50000 non-null  int64
#  4   length_of_stay         50000 non-null  int64
#  5   flight_hour            50000 non-null  int64
#  6   flight_day             50000 non-null  object
#  7   route                  50000 non-null  object
#  8   booking_origin         50000 non-null  object
#  9   wants_extra_baggage    50000 non-null  int64
#  10  wants_preferred_seat   50000 non-null  int64
#  11  wants_in_flight_meals  50000 non-null  int64
#  12  flight_duration        50000 non-null  float64
#  13  booking_complete       50000 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df.describe()
# Out:
#        num_passengers  purchase_lead  length_of_stay  flight_hour  \
# count    50000.000000   50000.000000     50000.00000  50000.00000
# mean         1.591240      84.940480        23.04456      9.06634
# std          1.020165      90.451378        33.88767      5.41266
# min          1.000000       0.000000         0.00000      0.00000
# 25%          1.000000      21.000000         5.00000      5.00000
# 50%          1.000000      51.000000        17.00000      9.00000
# 75%          2.000000     115.000000        28.00000     13.00000
# max          9.000000     867.000000       778.00000     23.00000
#
#        wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# count         50000.000000          50000.000000           50000.000000
# mean              0.668780              0.296960               0.427140
# std               0.470657              0.456923               0.494668
# min               0.000000              0.000000               0.000000
# ...

# %%
df.isnull().sum()
# Out:
# num_passengers           0
# sales_channel            0
# trip_type                0
# purchase_lead            0
# length_of_stay           0
# flight_hour              0
# flight_day               0
# route                    0
# booking_origin           0
# wants_extra_baggage      0
# wants_preferred_seat     0
# wants_in_flight_meals    0
# flight_duration          0
# booking_complete         0
# dtype: int64

# %%
numerical_df = df.select_dtypes(include=np.number)
numerical_df.shape[1]
# Out:
# 9

# %%
categorical_df = df.select_dtypes(include=['object'])
categorical_df.shape[1]
# Out:
# 5

# %%
corr = numerical_df.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 0               2      Internet  RoundTrip            262              19
# 1               1      Internet  RoundTrip            112              20
# 2               2      Internet  RoundTrip            243              22
# 3               1      Internet  RoundTrip             96              31
# 4               2      Internet  RoundTrip             68              22
#
#    flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 0            7        Sat  AKLDEL    New Zealand                    1
# 1            3        Sat  AKLDEL    New Zealand                    0
# 2           17        Wed  AKLDEL          India                    1
# 3            4        Sat  AKLDEL    New Zealand                    0
# 4           15        Wed  AKLDEL          India                    1
#
#    wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
l = df.columns
for i in l:
  print(f'The unique values of feature {i} -: {df[i].value_counts()}')
  print("------------------------------------------------------------")
# Out:
# The unique values of feature num_passengers -: num_passengers
# 1    31352
# 2    12804
# 3     2941
# 4     1784
# 5      561
# 6      289
# 7      114
# 8       89
# 9       66
# Name: count, dtype: int64
# ------------------------------------------------------------
# The unique values of feature sales_channel -: sales_channel
# Internet    44382
# Mobile       5618
# Name: count, dtype: int64
# ------------------------------------------------------------
# The unique values of feature trip_type -: trip_type
# RoundTrip     49497
# OneWay          387
# CircleTrip      116
# Name: count, dtype: int64
# ------------------------------------------------------------
# The unique values of feature purchase_lead -: purchase_lead
# 1      685
# 2      670
# 6      653
# 7      638
# 5      615
#       ...
# 435      1
# 606      1
# 483      1
# 516      1
# 867      1
# Name: count, Length: 470, dtype: int64
# ------------------------------------------------------------
# ...

# %%
booking_1 = df[df['booking_complete']==1]

# %%
booking_1.shape[0]
# Out:
# 7478

# %%
booking_0 = df[df['booking_complete']==0]

# %%
booking_0.shape[0]
# Out:
# 42522

# %%
df.shape
# Out:
# (50000, 14)

# %%
# Delete only the first 100 rows where 'booking_complete' is 0
df = df.drop(df[df['booking_complete'] == 0].head(39000).index)

# %%
df.shape
# Out:
# (11000, 14)

# %%
booking_1.head()
# Out:
#      num_passengers sales_channel  trip_type  purchase_lead  length_of_stay  \
# 82                1      Internet  RoundTrip             15              31
# 86                1      Internet  RoundTrip            156              19
# 94                1      Internet  RoundTrip            181              87
# 109               1        Mobile  RoundTrip            127              17
# 122               1      Internet  RoundTrip             42              17
#
#      flight_hour flight_day   route booking_origin  wants_extra_baggage  \
# 82            17        Mon  AKLKUL       Malaysia                    0
# 86            14        Mon  AKLKUL       Malaysia                    1
# 94             2        Tue  AKLKUL      Singapore                    1
# 109           16        Tue  AKLKUL       Malaysia                    1
# 122           14        Tue  AKLKUL       Malaysia                    0
#
#      wants_preferred_seat  wants_in_flight_meals  flight_duration  \
# ...

# %%
o = booking_1['booking_origin'].value_counts()[:20]
plt.figure(figsize=(7,7))
o.plot.barh(x= o[0],y=o[1],color='purple')
plt.title("Countries with holiday booking")
plt.show()
# Out:
# <ipython-input-22-bfc33b5df2a1>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   o.plot.barh(x= o[0],y=o[1],color='purple')

# %%
c = booking_1['sales_channel'].value_counts()
plt.figure(figsize=(7,7))
c.plot.barh(x= c[0],y=c[1],color='indigo')
plt.title("Sales channel with bookings")
plt.show()
# Out:
# <ipython-input-24-db32ad8299b2>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   c.plot.barh(x= c[0],y=c[1],color='indigo')

# %%
w = booking_1['trip_type'].value_counts()
plt.figure(figsize=(7,7))
w.plot.barh(color='red')
plt.title("Trip types in holiday bookings")
plt.show()

# %%
d = booking_1['flight_duration'].value_counts()
plt.figure(figsize=(7,7))
d.plot.barh(color='hotpink')
plt.title("Flight durations in holiday bookings")
plt.show()

# %%
h = booking_1['flight_hour'].value_counts()
plt.figure(figsize=(7,7))
h.plot.barh(x= h[0],y=h[1],color='black')
plt.title('Flight Hours in holiday bookings')
plt.show()

# %%
s = booking_1['length_of_stay'].value_counts()[:20]
plt.figure(figsize=(7,7))
s.plot.barh(color='darkblue')
plt.title('Lenght of stay in holiday bookings')
plt.show()

# %%
p = booking_1['num_passengers'].value_counts()
plt.figure(figsize=(7,7))
p.plot.barh(color='green')
plt.title('Number of passengers in holiday bookings')
plt.show()

# %%
route = booking_1['route'].value_counts()[:20]
plt.figure(figsize=(7,7))
route.plot.barh(color='orange')
plt.title('Routes in holiday bookings')
plt.show()

# %%
day = booking_1['flight_day'].value_counts()
plt.figure(figsize=(7,7))
day.plot.barh(color='brown')
plt.title('Flight Day in holiday bookings')
plt.show()

# %%
meal = booking_1['wants_in_flight_meals'].value_counts()
plt.figure(figsize=(7,7))
meal.plot.barh(color='grey')
plt.title('Extra flight meals in holiday bookings')
plt.show()

# %%
seat = booking_1['wants_preferred_seat'].value_counts()
plt.figure(figsize=(7,7))
seat.plot.barh(color='royalblue')
plt.title('Preffered seat in hoilday bookings')
plt.show()

# %%
baggage = booking_1['wants_extra_baggage'].value_counts()
plt.figure(figsize=(7,7))
baggage.plot.barh(color='lightblue')
plt.title('Extra baggage in holiday bookings')
plt.show()

# %%
lead = booking_1['purchase_lead'].value_counts()[:20]
plt.figure(figsize=(7,7))
lead.plot.barh(color='darkgrey')
plt.show()

# %%
booking_1.describe()
# Out:
#        num_passengers  purchase_lead  length_of_stay  flight_hour  \
# count     7478.000000    7478.000000     7478.000000  7478.000000
# mean         1.649906      80.167157       19.617679     9.158331
# std          1.065807      89.836401       33.909567     5.236860
# min          1.000000       0.000000        1.000000     0.000000
# 25%          1.000000      18.000000        5.000000     5.000000
# 50%          1.000000      46.000000        6.000000     9.000000
# 75%          2.000000     106.000000       23.000000    13.000000
# max          9.000000     867.000000      778.000000    23.000000
#
#        wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# count          7478.000000           7478.000000            7478.000000
# mean              0.745253              0.351565               0.458411
# std               0.435748              0.477491               0.498301
# min               0.000000              0.000000               0.000000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

columns_to_check = ['num_passengers', 'purchase_lead', 'length_of_stay', 'flight_hour', 'flight_duration']
# Plot boxplots for each column
plt.figure(figsize=(15, 10))
for i, column in enumerate(columns_to_check, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[column], color='skyblue')
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
df.shape
# Out:
# (11000, 14)

# %%
# Remove rows with outliers
for column in columns_to_check:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

# %%
df.describe()
# Out:
#        num_passengers  purchase_lead  length_of_stay  flight_hour  \
# count     8347.000000    8347.000000     8347.000000  8347.000000
# mean         1.472745      61.038936        8.563077     9.227028
# std          0.632848      56.415443        7.517497     5.266863
# min          1.000000       0.000000        1.000000     0.000000
# 25%          1.000000      18.000000        5.000000     5.000000
# 50%          1.000000      43.000000        6.000000     9.000000
# 75%          2.000000      86.000000        6.000000    13.000000
# max          3.000000     236.000000       35.000000    23.000000
#
#        wants_extra_baggage  wants_preferred_seat  wants_in_flight_meals  \
# count          8347.000000           8347.000000            8347.000000
# mean              0.661435              0.324428               0.421109
# std               0.473250              0.468189               0.493767
# min               0.000000              0.000000               0.000000
# ...

# %%
df.shape
# Out:
# (8347, 14)

# %%
# Plot boxplots for each column
plt.figure(figsize=(15, 10))
for i, column in enumerate(columns_to_check, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(x=df[column], color='skyblue')
    plt.title(column)
plt.tight_layout()
plt.show()

# %%
booking_1_clean = df[df['booking_complete']==1]
booking_0_clean = df[df['booking_complete']==0]

# %%
s = booking_1_clean['length_of_stay'].value_counts()[:20]
plt.figure(figsize=(7,7))
s.plot.barh(color='darkblue')
plt.title('Length of stay in holiday bookings')
plt.show()

# %%
s = booking_1_clean['purchase_lead'].value_counts()[:20]
plt.figure(figsize=(7,7))
s.plot.barh(color='lightblue')
plt.title('Purchase Lead in holiday bookings')
plt.show()

# %%
s = booking_0_clean['purchase_lead'].value_counts()[:20]
plt.figure(figsize=(7,7))
s.plot.barh(color='lightblue')
plt.title('Purchase Lead in no bookings')
plt.show()

# %%
categorical_df.head()
# Out:
#   sales_channel  trip_type flight_day   route booking_origin
# 0      Internet  RoundTrip        Sat  AKLDEL    New Zealand
# 1      Internet  RoundTrip        Sat  AKLDEL    New Zealand
# 2      Internet  RoundTrip        Wed  AKLDEL          India
# 3      Internet  RoundTrip        Sat  AKLDEL    New Zealand
# 4      Internet  RoundTrip        Wed  AKLDEL          India

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for i in categorical_df.columns:
  df[i] = le.fit_transform(df[i])

# %%
df.head()
# Out:
#      num_passengers  sales_channel  trip_type  purchase_lead  length_of_stay  \
# 82                1              0          2             15              31
# 86                1              0          2            156              19
# 109               1              1          2            127              17
# 122               1              0          2             42              17
# 136               3              0          2            229              17
#
#      flight_hour  flight_day  route  booking_origin  wants_extra_baggage  \
# 82            17           1      0              31                    0
# 86            14           1      0              31                    1
# 109           16           5      0              31                    1
# 122           14           5      0              31                    0
# 136           13           1      0              31                    1
#
# ...

# %%
x = df.drop(columns='booking_complete',axis=1)
y = df['booking_complete']

# %%
x.head()
# Out:
#      num_passengers  sales_channel  trip_type  purchase_lead  length_of_stay  \
# 82                1              0          2             15              31
# 86                1              0          2            156              19
# 109               1              1          2            127              17
# 122               1              0          2             42              17
# 136               3              0          2            229              17
#
#      flight_hour  flight_day  route  booking_origin  wants_extra_baggage  \
# 82            17           1      0              31                    0
# 86            14           1      0              31                    1
# 109           16           5      0              31                    1
# 122           14           5      0              31                    0
# 136           13           1      0              31                    1
#
# ...

# %%
y.head()
# Out:
# 82     1
# 86     1
# 109    1
# 122    1
# 136    1
# Name: booking_complete, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_scaled = scaler.fit_transform(x)
x_scaled = pd.DataFrame(x_scaled, columns=x.columns)

# %%
x.describe()
# Out:
#        num_passengers  sales_channel    trip_type  purchase_lead  \
# count     8347.000000    8347.000000  8347.000000    8347.000000
# mean         1.472745       0.109141     1.991734      61.038936
# std          0.632848       0.311835     0.108598      56.415443
# min          1.000000       0.000000     0.000000       0.000000
# 25%          1.000000       0.000000     2.000000      18.000000
# 50%          1.000000       0.000000     2.000000      43.000000
# 75%          2.000000       0.000000     2.000000      86.000000
# max          3.000000       1.000000     2.000000     236.000000
#
#        length_of_stay  flight_hour   flight_day        route  booking_origin  \
# count     8347.000000  8347.000000  8347.000000  8347.000000     8347.000000
# mean         8.563077     9.227028     3.115131   292.452019       27.212771
# std          7.517497     5.266863     2.053104   160.442985       18.453821
# ...

# %%
x_scaled.describe()
# Out:
#        num_passengers  sales_channel     trip_type  purchase_lead  \
# count    8.347000e+03   8.347000e+03  8.347000e+03   8.347000e+03
# mean    -1.877018e-16  -8.512552e-19 -1.881274e-16   2.468640e-17
# std      1.000060e+00   1.000060e+00  1.000060e+00   1.000060e+00
# min     -7.470557e-01  -3.500173e-01 -1.834145e+01  -1.082019e+00
# 25%     -7.470557e-01  -3.500173e-01  7.612389e-02  -7.629385e-01
# 50%     -7.470557e-01  -3.500173e-01  7.612389e-02  -3.197709e-01
# 75%      8.331961e-01  -3.500173e-01  7.612389e-02   4.424774e-01
# max      2.413448e+00   2.857002e+00  7.612389e-02   3.101483e+00
#
#        length_of_stay   flight_hour    flight_day         route  \
# count    8.347000e+03  8.347000e+03  8.347000e+03  8.347000e+03
# mean    -5.958787e-18 -5.618284e-17  9.576621e-17 -7.491046e-17
# std      1.000060e+00  1.000060e+00  1.000060e+00  1.000060e+00
# min     -1.006123e+00 -1.752007e+00 -1.517370e+00 -1.822888e+00
# ...

# %% [markdown]
# # TRAINING

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state= 42)

# %%
rf = RandomForestClassifier(class_weight='balanced')
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred = rf.predict(x_test)
print(f'Accuracy score of model is : {accuracy_score(y_test,y_pred)}')
# Out:
# Accuracy score of model is : 0.9191616766467066

# %%
print(f'Classification report :\n {classification_report(y_test,y_pred)}')
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89       570
#            1       0.98      0.90      0.94      1100
#
#     accuracy                           0.92      1670
#    macro avg       0.90      0.93      0.91      1670
# weighted avg       0.93      0.92      0.92      1670

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)
print(cm)

plt.figure(figsize=(6,6))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=['0','1'], yticklabels=['0','1'])
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[545  25]
#  [110 990]]

# %%
df.shape
# Out:
# (8347, 14)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a trained RandomForestClassifier model 'rf'
importances = rf.feature_importances_

# Get feature names from the original DataFrame (assuming it's called 'df')
# Replace 'df' with the actual name of your DataFrame if different
feature_names = x.columns  # Assuming 'x' was the DataFrame before PCA

# Create a DataFrame to display feature names and their respective importances
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importances})

# Sort by importance values to find the most important features
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the most important features
print(feature_importance_df)

# Optional: Plot the feature importances
plt.figure(figsize=(6, 6))
plt.barh(feature_importance_df['Feature'], feature_importance_df['Importance'])
plt.xlabel('Feature Importance')
plt.title('Feature Importance - RandomForestClassifier')
plt.show()
# Out:
#                   Feature  Importance
# 4          length_of_stay    0.461650
# 7                   route    0.232772
# 8          booking_origin    0.065282
# 3           purchase_lead    0.065192
# 5             flight_hour    0.047824
# 12        flight_duration    0.039725
# 6              flight_day    0.031887
# 9     wants_extra_baggage    0.014562
# 0          num_passengers    0.014549
# 10   wants_preferred_seat    0.009112
# 11  wants_in_flight_meals    0.008885
# 1           sales_channel    0.007490
# 2               trip_type    0.001070
